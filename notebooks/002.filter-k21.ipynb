# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.2.4'

# %% [markdown]
# ## Assess SRA Search Results

# %% [markdown]
# ### Load Results

# %%
# %%bash
#
# #curl -L https://osf.io/n8zga/download -o ../output.genome-magsearch/results/jb.k21.csv.gz
# ls ../output.genome-magsearch/results
# Out:
# jb.k21.csv.gz
# jb.k31.csv
# jb.k31.csv.gz

# %%
# read in k=21 SRA search results
ms21 = pd.read_csv("../output.genome-magsearch/results/jb.k21.csv.gz",
                   sep=",",
                   quotechar="'",
                   header=0,
                   names=["search_genome", "metagenome", "containment"])
ms21
# Out:
#         search_genome                                         metagenome  \
# 0          2523533589  /group/ctbrowngrp/irber/data/wort-data/wort-sr...
# 1          2561511076  /group/ctbrowngrp/irber/data/wort-data/wort-sr...
# 2          2563366544  /group/ctbrowngrp/irber/data/wort-data/wort-sr...
# 3          2630968516  /group/ctbrowngrp/irber/data/wort-data/wort-sr...
# 4          2630968951  /group/ctbrowngrp/irber/data/wort-data/wort-sr...
# ...               ...                                                ...
# 4496729    2534682289  /group/ctbrowngrp/irber/data/wort-data/wort-sr...
# 4496730    2558860163  /group/ctbrowngrp/irber/data/wort-data/wort-sr...
# 4496731    2561511058  /group/ctbrowngrp/irber/data/wort-data/wort-sr...
# 4496732    2561511071  /group/ctbrowngrp/irber/data/wort-data/wort-sr...
# 4496733    2558860179  /group/ctbrowngrp/irber/data/wort-data/wort-sr...
#
#          containment
# 0           0.043357
# 1           0.010787
# 2           0.010702
# 3           0.012132
# 4           0.010401
# ...              ...
# 4496729     0.011494
# 4496730     0.017456
# 4496731     0.015075
# 4496732     0.010786
# 4496733     0.019204
#
# [4496734 rows x 3 columns]

# %%
# Fix names so it's easier to query
ms21['search_genome'] = ms21['search_genome'].str.replace(r"'(?P<id>.*)'", lambda m: m.group("id"), regex=True)
ms21['metagenome'] = ms21['metagenome'].str.replace(r".*/(?P<id>.*).sig.*", lambda m: m.group("id"), regex=True)
ms21['accession'] = ms21['search_genome'].str.split(" ", 1, expand=True)[0]
ms21
# Out:
#         search_genome   metagenome  containment   accession
# 0          2523533589    SRR532530     0.043357  2523533589
# 1          2561511076  SRR12927917     0.010787  2561511076
# 2          2563366544   ERR1913926     0.010702  2563366544
# 3          2630968516   ERR1913926     0.012132  2630968516
# 4          2630968951   SRR5131961     0.010401  2630968951
# ...               ...          ...          ...         ...
# 4496729    2534682289  SRR10692326     0.011494  2534682289
# 4496730    2558860163  SRR10692326     0.017456  2558860163
# 4496731    2561511058  SRR10692326     0.015075  2561511058
# 4496732    2561511071  SRR10692326     0.010786  2561511071
# 4496733    2558860179  SRR10692326     0.019204  2558860179
#
# [4496734 rows x 4 columns]

# %%
# print some summary info for 50%+ containment
search_ksize = 21
num_search_genomes = len(ms21["search_genome"].unique())
num_search_genomes_with_matches = len(ms21[ms21['containment'] > 0.5]["search_genome"].unique())
num_unique_metagenome_matches = len(ms21[ms21['containment'] > 0.5]["metagenome"].unique())

print(f"Search ksize: {search_ksize}")
print(f"# Search genomes: {num_search_genomes}")
print(f"# Search genomes with 'good' metagenome matches: {num_search_genomes_with_matches}")
print(f"# Metagenomes with >50% containment of at least one search genome: {num_unique_metagenome_matches}")
# Out:
# Search ksize: 21
# # Search genomes: 95
# # Search genomes with 'good' metagenome matches: 35
# # Metagenomes with >50% containment of at least one search genome: 493

# %%
# Summarize 30% containment, just out of curiosity
search_ksize = 21
c30_matches = len(ms21[ms21['containment'] > 0.3]["metagenome"].unique())
print(f"Search ksize: {search_ksize}")
print(f"# Metagenomes with >30% containment of at least one search genome: {c30_matches}")
# Out:
# Search ksize: 21
# # Metagenomes with >30% containment of at least one search genome: 848

# %% [markdown]
# ## Explore & Summarize >50% containment results

# %%
#subset to just >50% containment; sort by containment & look at top metagenome matches
ms21_c50 = ms21[ms21['containment'] > 0.5]
ms21_c50 = ms21_c50.sort_values(by="containment", ascending=False, ignore_index=True)
ms21_c50
# Out:
#       search_genome   metagenome  containment       accession
# 0         637000176   ERR3377554     1.000000       637000176
# 1        2597490271   SRR2133847     1.000000      2597490271
# 2      ERR4765901_1   ERR4765901     1.000000    ERR4765901_1
# 3         637000176   ERR3386158     1.000000       637000176
# 4         637000176   ERR3415696     1.000000       637000176
# ..              ...          ...          ...             ...
# 524      2667527558   SRR8369521     0.503226      2667527558
# 525      2757320367  SRR12349262     0.503089      2757320367
# 526      2561511236   SRR5371507     0.503016      2561511236
# 527       648028044  SRR10136702     0.502523       648028044
# 528  L_09_tn_tnf1_1  SRR13002033     0.501538  L_09_tn_tnf1_1
#
# [529 rows x 4 columns]

# %% [markdown]
# ## Save some better formatted results

# %%
# save sorted containment-50 csvs
# !mkdir -p ../output.genome-magsearch/processed_results

ms21_c50.to_csv("../output.genome-magsearch/processed_results/jb.sra-search.k21-c50.csv", index=False)

# %%
# save list of all unique matched metagenomes
m21_metagenomes = ms21_c50["metagenome"].unique()
# !mkdir -p ../output.magsearch/processed_results
with open('../output.genome-magsearch/processed_results/ms21_c50.unique-metagenomes.txt', 'w') as out:
    for mg in list(m21_metagenomes):
        out.write(f"{mg}\n")
m21_metagenomes
# Out:
# array(['ERR3377554', 'SRR2133847', 'ERR4765901', 'ERR3386158',
#        'ERR3415696', 'SRR4046667', 'ERR3370534', 'ERR3348307',
#        'ERR3325125', 'ERR3140035', 'ERR3385286', 'ERR3374312',
#        'ERR3348960', 'ERR3363815', 'ERR3365599', 'ERR4765900',
#        'ERR3444455', 'ERR3140034', 'ERR3427528', 'SRR4046666',
#        'ERR3458908', 'ERR3404460', 'ERR3140033', 'ERR4765898',
#        'ERR3318558', 'ERR3485549', 'ERR3404461', 'ERR3386235',
#        'ERR3140022', 'ERR4765902', 'ERR4765899', 'ERR3140021',
#        'ERR3140023', 'SRR5416892', 'ERR3139975', 'ERR2856160',
#        'SRR8369453', 'SRR12635561', 'ERR3386233', 'ERR2856158',
#        'ERR3139973', 'ERR2856159', 'ERR3139974', 'SRR9841585',
#        'ERR3450189', 'SRR8369705', 'SRR8369523', 'SRR8369653',
#        'SRR8369569', 'SRR8369694', 'ERR5094874', 'SRR13206618',
#        'SRR8369545', 'SRR8369423', 'SRR12635522', 'SRR8369395',
#        'SRR8369531', 'SRR8369497', 'SRR12635555', 'SRR8369426',
#        'SRR13178630', 'SRR13203221', 'SRR8369679', 'SRR13170451',
#        'SRR13178627', 'SRR8369516', 'SRR8369515', 'SRR13188906',
#        'SRR13300764', 'ERR3313812', 'SRR9040418', 'SRR11119767',
#        'SRR8369611', 'SRR6262394', 'SRR3112444', 'SRR11119763',
#        'SRR8369704', 'SRR11119765', 'SRR12635537', 'SRR12635535',
#        'SRR11119764', 'SRR13304626', 'ERR2027926', 'SRR8142951',
#        'SRR12635544', 'ERR3275096', 'ERR3360142', 'ERR3351010',
#        'ERR3378028', 'ERR3339000', 'ERR3479002', 'ERR3323641',
#        'SRR5877074', 'ERR3434195', 'ERR3346153', 'ERR3358498',
#        'ERR5094903', 'ERR3453828', 'SRR11119762', 'SRR6847343',
#        'ERR2244423', 'SRR12635533', 'ERR3220190', 'ERR2856157',
#        'ERR3139972', 'SRR4046669', 'SRR7547275', 'ERR3220222',
#        'ERR3139971', 'ERR2856156', 'ERR3415529', 'SRR5251628',
#        'ERR3275104', 'ERR3201418', 'SRR5877079', 'SRR11119766',
#        'SRR13167734', 'SRR13167589', 'ERR3139957', 'ERR2856142',
#        'ERR3139956', 'ERR2856141', 'ERR3139955', 'ERR2856140',
#        'SRR12063320', 'ERR2856173', 'ERR2856174', 'SRR10769902',
#        'ERR3336655', 'ERR2856175', 'SRR6316201', 'ERR3792780',
#        'ERR3139970', 'ERR2856155', 'SRR12635564', 'ERR5094904',
#        'ERR1868832', 'SRR5877072', 'SRR5877080', 'SRR5877073',
#        'SRR8369552', 'SRR8369554', 'ERR5094852', 'ERR3140040',
#        'SRR8369528', 'SRR5826738', 'SRR060038', 'ERR3140041',
#        'ERR3140039', 'SRR13740997', 'ERR3220208', 'SRR1779403',
#        'SRR8369604', 'SRR8834104', 'SRR8834102', 'SRR8834101',
#        'SRR8834103', 'ERR5094865', 'ERR1868840', 'SRR8834100',
#        'ERR3140012', 'SRR513797', 'ERR3140013', 'ERR3140014',
#        'SRR8369419', 'ERR1868855', 'ERR1868842', 'ERR3143222',
#        'SRR1779378', 'SRR10333445', 'ERR1868862', 'SRR9008756',
#        'SRR1535359', 'SRR9008757', 'SRR061282', 'SRR9217452',
#        'SRR5690554', 'SRR8834099', 'SRR514306', 'SRR8369573', 'SRR346671',
#        'SRR061320', 'SRR12635546', 'ERR4333938', 'ERR4765908',
#        'ERR1868841', 'SRR3678334', 'ERR1868857', 'SRR1783724',
#        'SRR514178', 'ERR1868860', 'ERR1868851', 'SRR12785895',
#        'ERR1868861', 'SRR12450927', 'ERR2732551', 'ERR1868858',
#        'ERR1868844', 'SRR5690606', 'ERR3224585', 'SRR5400274',
#        'SRR5877081', 'ERR1868839', 'ERR3275133', 'SRR062501',
#        'SRR5877082', 'ERR1868845', 'ERR1868856', 'SRR8834174',
#        'ERR1868859', 'ERR1868846', 'ERR4407004', 'ERR1868831',
#        'ERR1868843', 'ERR1868833', 'SRR10136706', 'SRR5877076',
#        'ERR2019376', 'SRR10498319', 'ERR3471123', 'SRR7609838',
#        'ERR3358468', 'ERR1868838', 'SRR11661717', 'SRR13300909',
#        'ERR1868849', 'ERR1868835', 'ERR1864492', 'ERR1868854',
#        'ERR1868834', 'ERR1868853', 'SRR062511', 'SRR12635563',
#        'SRR5405676', 'ERR1868836', 'SRR8961007', 'SRR10136732',
#        'SRR8834093', 'ERR2019381', 'ERR1868848', 'SRR11854485',
#        'SRR6847295', 'SRR10136735', 'SRR13167568', 'ERR5094899',
#        'ERR1868852', 'SRR5877084', 'ERR3140029', 'SRR12649112',
#        'SRR5405677', 'SRR11058229', 'SRR514846', 'SRR513452',
#        'SRR12316199', 'SRR11058231', 'SRR6747967', 'SRR13001971',
#        'ERR1868837', 'SRR11058230', 'SRR14489481', 'SRR514848',
#        'ERR3140027', 'ERR3140028', 'SRR7624250', 'SRR9921013',
#        'SRR6847314', 'SRR13300884', 'SRR11749279', 'SRR9217388',
#        'ERR2013623', 'SRR13442943', 'SRR5405675', 'SRR7002163',
#        'ERR3525314', 'SRR2565997', 'SRR12785912', 'SRR11482394',
#        'ERR2027927', 'ERR4765907', 'SRR10276561', 'SRR10507662',
#        'SRR11236186', 'SRR7215438', 'SRR8369530', 'SRR11236218',
#        'SRR9184936', 'ERR3500829', 'SRR13167521', 'ERR4765912',
#        'SRR8266643', 'ERR3224587', 'ERR3500826', 'SRR8369681',
#        'SRR8616228', 'SRR8266642', 'SRR6706335', 'SRR8616225',
#        'SRR10136733', 'SRR9866663', 'SRR10136705', 'SRR10136655',
#        'SRR7547279', 'SRR9841584', 'SRR10136652', 'ERR1868830',
#        'SRR10136734', 'SRR062305', 'SRR6847270', 'SRR8369401',
#        'SRR13167518', 'SRR062281', 'SRR10136731', 'SRR061281',
#        'ERR5094897', 'SRR8266644', 'ERR2014367', 'SRR10176800',
#        'ERR1868850', 'SRR10479842', 'SRR5877071', 'SRR13213985',
#        'SRR13167585', 'SRR10769913', 'ERR4765910', 'ERR2027902',
#        'SRR1804433', 'ERR4765909', 'SRR514842', 'SRR12649045',
#        'SRR7448282', 'SRR11487840', 'SRR061289', 'ERR3515536',
#        'SRR3586059', 'SRR13300802', 'ERR2019372', 'SRR8369680',
#        'SRR13774592', 'SRR4028154', 'SRR8731670', 'SRR9921034',
#        'SRR9177322', 'SRR9217401', 'ERR2856144', 'ERR3139959',
#        'SRR8961000', 'ERR3139960', 'ERR2856145', 'ERR5094887',
#        'ERR4765911', 'SRR10136651', 'ERR2856183', 'SRR8266637',
#        'SRR9921046', 'SRR13765540', 'ERR4765913', 'SRR10136649',
#        'SRR6847337', 'SRR10136656', 'ERR3950368', 'SRR8143003',
#        'SRR5818537', 'SRR7403932', 'SRR6706336', 'SRR10136653',
#        'SRR10136650', 'SRR8707082', 'SRR513812', 'ERR2014358',
#        'ERR5094901', 'SRR13001969', 'ERR2019359', 'ERR4622890',
#        'ERR3140246', 'ERR2373094', 'SRR1804162', 'SRR10154297',
#        'SRR8369437', 'SRR13765539', 'SRR061286', 'SRR8707083',
#        'SRR13197234', 'SRR13203225', 'SRR513440', 'SRR12649113',
#        'ERR3799301', 'SRR8925776', 'SRR10769903', 'ERR2856184',
#        'ERR2732557', 'SRR8369474', 'ERR4765906', 'SRR948118', 'SRR061316',
#        'SRR3546778', 'SRR14311777', 'SRR6747972', 'ERR2019361',
#        'SRR13001973', 'SRR8132908', 'ERR2019371', 'SRR7193024',
#        'SRR12635536', 'ERR5094855', 'SRR8369442', 'SRR059918',
#        'SRR8834096', 'SRR10136704', 'ERR552962', 'SRR10176810',
#        'SRR9040439', 'ERR4623503', 'SRR8387719', 'SRR10154287',
#        'ERR5094905', 'ERR3139958', 'ERR2856143', 'SRR059919',
#        'SRR13739760', 'ERR2198692', 'SRR11970093', 'SRR9684996',
#        'ERR2019375', 'SRR10769912', 'SRR12785939', 'ERR3143217',
#        'SRR11236191', 'ERR4623505', 'ERR3596491', 'ERR525595',
#        'SRR5548728', 'SRR1804560', 'SRR059814', 'SRR8731662',
#        'SRR9217416', 'SRR532419', 'SRR6257430', 'SRR8387715', 'SRR532424',
#        'SRR549454', 'SRR061501', 'SRR12635552', 'ERR4623504',
#        'ERR3275106', 'SRR513771', 'SRR6748170', 'SRR533395',
#        'SRR11880801', 'SRR062302', 'SRR11293606', 'SRR10136654',
#        'ERR2856148', 'ERR3139963', 'SRR513813', 'ERR2014354', 'SRR537741',
#        'SRR062298', 'SRR11482326', 'ERR3799300', 'SRR061502',
#        'SRR8132901', 'SRR533396', 'SRR8114050', 'SRR533266', 'SRR533309',
#        'SRR5892196', 'SRR10682134', 'SRR5548730', 'ERR3220207',
#        'SRR532396', 'SRR059815', 'SRR12619557', 'SRR6847291',
#        'SRR10034930', 'ERR3274615', 'ERR4129791', 'SRR539307',
#        'SRR532768', 'SRR6242912', 'SRR549537', 'ERR2856182', 'ERR2856147',
#        'ERR3139962', 'SRR8132910', 'SRR11482339', 'SRR11482341',
#        'SRR10258567', 'SRR540934', 'SRR8369521', 'SRR12349262',
#        'SRR5371507', 'SRR10136702', 'SRR13002033'], dtype=object)
